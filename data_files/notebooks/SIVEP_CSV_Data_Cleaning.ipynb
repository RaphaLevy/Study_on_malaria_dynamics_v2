# %%
import numpy as np
import pandas as pd
import glob
import os
import regex as re

# %%
input_folder = "../../data_files/data/sivep_notification_data/malaria_notification_data_csv/"
output_folder = "../../data_files/data/sivep_notification_data/treated_malaria_notification_data/"

# %%
# Create output folder if it doesn't exist
os.makedirs(output_folder, exist_ok=True)

# %%
# Columns to drop
columns_to_drop = ['Unnamed: 0', 'DT_TRATA', 'ESQUEMA', 'CO_FORMA_SANGUINEA', 
                   'CO_FORMA_TECIDUAL_GAMETOCITO', 'EXAME ', 'NU_ATIVIDADE_G6PD', 
                   'NU_HEMOGLOBINA_TOTAL', 'EXAMINADOR', 'ID_LVC ', 'GESTANTE ', 
                   'AMAMENTANDO', 'TEMP_AMAMENT', 'DIMEA_AMAMENT', 'NIV_ESCO', 'FALCIPARUM',
                   'QTD_PARA', 'QTD_CRUZ', 'SEXO', 'RACA', 'PESO', 'COD_AGEN', 'DT_NASCI', 'ID_PACIE',
                   'ID_DIMEA', 'COD_UNIN', 'COD_NOTI', 'TIPO_LAM', 'DT_ENVLO', 'HEMOPARASI', 'DT_DIGIT', 'VIVAX']

# %%
# Process each year from 2003 to 2023
for year in range(2003, 2024):
    year_suffix = str(year)[-2:]
    input_path = f"../../data_files/data/sivep_notification_data/malaria_notification_data_csv/NOTIPO{year_suffix}.csv"
    
    # Read and process
    df = pd.read_csv(input_path, low_memory=False)
    df = df.drop(columns=columns_to_drop, errors='ignore')
    df = df.dropna(axis=1, how='all')
    df = df[df['RES_EXAM'] == 4]
    df = df[df['PAIS_INF'] == 1]
    df = df[df['PAIS_RES'] == 1]
    df = df.drop(columns=['RES_EXAM', 'PAIS_INF', 'PAIS_RES'])
    
    # Create named dataframe
    globals()[f"malaria_{year}_df"] = df
    
    # Save to CSV
    output_path = f"../../data_files/data/sivep_notification_data/treated_malaria_notification_data/malaria_vivax_{year}_treated.csv"
    df.to_csv(output_path, index=False)
    
    print(f"✓ Created malaria_{year}_df with {len(df):,} rows")
# Out:
# ✓ Created malaria_2003_df with 355,337 rows
# ✓ Created malaria_2004_df with 407,517 rows
# ✓ Created malaria_2005_df with 539,309 rows
# ✓ Created malaria_2006_df with 492,234 rows
# ✓ Created malaria_2007_df with 433,067 rows
# ✓ Created malaria_2008_df with 313,007 rows
# ✓ Created malaria_2009_df with 304,489 rows
# ✓ Created malaria_2010_df with 347,784 rows
# ✓ Created malaria_2011_df with 274,030 rows
# ✓ Created malaria_2012_df with 233,369 rows
# ✓ Created malaria_2013_df with 162,593 rows
# ✓ Created malaria_2014_df with 134,701 rows
# ✓ Created malaria_2015_df with 142,678 rows
# ✓ Created malaria_2016_df with 129,602 rows
# ✓ Created malaria_2017_df with 208,280 rows
# ✓ Created malaria_2018_df with 209,999 rows
# ✓ Created malaria_2019_df with 165,295 rows
# ✓ Created malaria_2020_df with 145,172 rows
# ✓ Created malaria_2021_df with 137,004 rows
# ✓ Created malaria_2022_df with 127,375 rows
# ✓ Created malaria_2023_df with 138,368 rows

# %%
malaria_2003_df = pd.read_csv('../../data_files/data/sivep_notification_data/treated_malaria_notification_data/malaria_vivax_2003_treated.csv')
malaria_2003_df
# Out:
#         DT_NOTIF SEM_NOTI  UF_NOTIF  MUN_NOTI  UF_RESID  MUN_RESI  LOC_RESI  \
# 0       27/01/03  05/2003        21    210290      21.0  210055.0      29.0
# 1       20/03/03  12/2003        21    210232      21.0  210232.0       NaN
# 2       10/07/03  28/2003        21    210232      21.0  210203.0      55.0
# 3       27/01/03  05/2003        21    210232      21.0  210203.0      55.0
# 4       04/04/03  14/2003        21    210232      21.0  210203.0       NaN
# ...          ...      ...       ...       ...       ...       ...       ...
# 355332  14/11/03  46/2003        51    510330      51.0  510330.0       1.0
# 355333  27/01/03  05/2003        21    211050      21.0  211050.0      47.0
# 355334  01/10/03  40/2003        15    150140      15.0  150140.0      99.0
# 355335  10/01/03  02/2003        15    150590      15.0  150590.0     140.0
# 355336  11/12/03  50/2003        13    130120      13.0  130120.0       NaN
#
#         SINTOMAS  DT_SINTO  COD_OCUP  UF_INFEC  MUN_INFE  LOC_INFE  DT_EXAME
# 0              1  25/01/03      99.0      21.0  210055.0      29.0  27/01/03
# 1              1  18/03/03      11.0      21.0  210203.0      41.0  20/03/03
# 2              1  06/07/03       1.0      21.0  210203.0      55.0  10/07/03
# 3              1  26/01/03       1.0      21.0  210203.0      55.0  27/01/03
# 4              1  01/04/03       3.0      21.0  210203.0      88.0  04/04/03
# ...          ...       ...       ...       ...       ...       ...       ...
# 355332         1  13/11/03      11.0      11.0  110005.0       NaN  14/11/03
# 355333         1  20/01/03       5.0      15.0  150360.0       NaN  27/01/03
# 355334         1  29/09/03       8.0      13.0  130290.0       NaN  01/10/03
# 355335         1  06/01/03      11.0      15.0  150590.0       NaN  10/01/03
# 355336         1  19/12/03       NaN      13.0  130120.0       NaN  11/12/03
#
# [355337 rows x 14 columns]

# %%
malaria_2023_df = pd.read_csv('../../data_files/data/sivep_notification_data/treated_malaria_notification_data/malaria_vivax_2023_treated.csv')
malaria_2023_df
# Out:
#         DT_NOTIF SEM_NOTI  UF_NOTIF  MUN_NOTI  UF_RESID  MUN_RESI  LOC_RESI  \
# 0       04/03/23  09/2023        13    130260      13.0  130260.0      83.0
# 1       04/05/23  18/2023        13    130260      13.0  130260.0     175.0
# 2       11/01/23  02/2023        13    130260      13.0  130260.0     568.0
# 3       19/04/23  16/2023        13    130260      13.0  130260.0     568.0
# 4       19/04/23  16/2023        13    130260      13.0  130260.0     568.0
# ...          ...      ...       ...       ...       ...       ...       ...
# 138363  21/09/23  38/2023        21    210177      21.0  210177.0       5.0
# 138364  13/10/23  41/2023        12    120045      13.0  130070.0       NaN
# 138365  25/10/23  43/2023        14    140015      14.0  140010.0    1148.0
# 138366  29/09/23  39/2023        16    160060      16.0  160060.0      32.0
# 138367  26/09/23  39/2023        16    160025      16.0  160025.0      30.0
#
#         SINTOMAS  DT_SINTO  COD_OCUP  UF_INFEC  MUN_INFE  LOC_INFE  DT_EXAME
# 0              1  27/02/23      11.0      13.0  130260.0     565.0  04/03/23
# 1              1  30/04/23      11.0      13.0  130260.0     568.0  04/05/23
# 2              1  10/01/23       3.0      13.0  130260.0     568.0  11/01/23
# 3              2       NaN       1.0      13.0  130260.0     568.0  19/04/23
# 4              1  16/04/23       1.0      13.0  130260.0     568.0  19/04/23
# ...          ...       ...       ...       ...       ...       ...       ...
# 138363         1  20/09/23       5.0      15.0  150360.0       NaN  21/09/23
# 138364         1  11/01/23       7.0      13.0  130070.0       NaN  13/10/23
# 138365         1  23/10/23       2.0      14.0  140005.0       NaN  25/10/23
# 138366         1  26/09/23      11.0      16.0  160027.0       NaN  29/09/23
# 138367         1  23/09/23      11.0      16.0  160053.0       NaN  26/09/23
#
# [138368 rows x 14 columns]
